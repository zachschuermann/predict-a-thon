# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import Binarizer
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
from bayes_opt import BayesianOptimization

# %%
### Constants
seed = 69
cv_size = .3

train = pd.read_csv("data/Train.csv", encoding="ISO-8859-1")
test = pd.read_csv("data/Test.csv", encoding="ISO-8859-1")

X = train.loc[:, train.columns != 'revenue']
y = train["revenue"]

# encode string input values as integers
features = []
encode_cols = ["month", "channelGrouping", "browser", "operatingSystem", "deviceCategory", "continent", 
                "subContinent", "country", "region", "metro", "city", "topLevelDomain", "campaign", "source", 
                "medium", "keyword", "referralPath", "adContent", "adwordsClickInfo.page", "adwordsClickInfo.slot",
                "adwordsClickInfo.adNetworkType", "bounces", "newVisits"]

other_cols = ["visitNumber", "timeSinceLastVisit", "isMobile", "isTrueDirect", "hits", "pageviews"]

# encode string input values as integers
encoded_x = None
for i in encode_cols:
    col = X[i].apply(str)
    label_encoder = LabelEncoder()
    feature = label_encoder.fit_transform(col.fillna('0'))
    feature = feature.reshape(X.shape[0], 1)
    onehot_encoder = OneHotEncoder(sparse=False)
    feature = onehot_encoder.fit_transform(feature)
    if encoded_x is None:
        encoded_x = feature
    else:
        encoded_x = np.concatenate((encoded_x, feature), axis=1)
print("X shape: ", encoded_x.shape)

X = np.concatenate((X[other_cols].fillna(0), encoded_x), axis=1)
y = Binarizer().transform(y.values.reshape(-1, 1))

X_train, X_cv, y_train, y_cv = train_test_split(X, y, test_size=cv_size)#, random_state=seed)
# Out:
# X shape:  (83578, 2498)

# %%
def xgbf(n_components, lamb, alpha):
    pca = PCA(n_components=int(n_components))
    X_train1 = pca.fit_transform(X_train)
    X_cv1 = pca.transform(X_cv)
    xgtrain = xgb.DMatrix(X_train1, y_train)
    xgcv = xgb.DMatrix(X_cv1, y_cv)
    # Specify sufficient boosting iterations to reach a minimum
    num_round = 5000
    evallist = [(xgcv, 'eval'), (xgtrain, 'train')]
    # Leave most parameters as default
    param = {'objective': 'binary:logistic',
             'tree_method': 'gpu_hist', # Use GPU accelerated algorithm
             'lambda': lamb,
             'alpha': alpha,
             }
    bst = xgb.train(param, xgtrain, num_round, evallist, early_stopping_rounds=10, verbose_eval = 10)
    
    pred = bst.predict(xgcv)
    
    f1_list = []
    thresholds = np.linspace(0.15, .55, 100)
    for i in thresholds:
        bin_pred = Binarizer(threshold=i).transform(pred.reshape(-1,1))
        f1 = f1_score(y_cv, bin_pred)
        f1_list.append(f1)
#     fig, ax = plt.subplots(figsize=(20, 10))
#     plt.plot(f1_list)
    return np.max(f1_list)

# %%
xgbf(100, 1.1, .1)
# Out:
# [0]	eval-error:0.05755	train-error:0.051774
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051169	train-error:0.041707
# [20]	eval-error:0.05073	train-error:0.036989
# [30]	eval-error:0.050371	train-error:0.032442
# [40]	eval-error:0.051169	train-error:0.027246
# [50]	eval-error:0.051288	train-error:0.02246
# [60]	eval-error:0.051926	train-error:0.018682
# [70]	eval-error:0.051886	train-error:0.015606
# [80]	eval-error:0.051847	train-error:0.012734
# [90]	eval-error:0.052844	train-error:0.010461
# [100]	eval-error:0.053601	train-error:0.008444
# [110]	eval-error:0.053801	train-error:0.006632
# [120]	eval-error:0.053601	train-error:0.005453
# [130]	eval-error:0.053641	train-error:0.00388
# [140]	eval-error:0.053442	train-error:0.002957
# [150]	eval-error:0.053442	train-error:0.002325
# [160]	eval-error:0.05396	train-error:0.001521
# [170]	eval-error:0.054559	train-error:0.001196
# [180]	eval-error:0.054439	train-error:0.00106
# [190]	eval-error:0.053881	train-error:0.000855
# [200]	eval-error:0.05412	train-error:0.00065
# [210]	eval-error:0.054279	train-error:0.000427
# [220]	eval-error:0.05408	train-error:0.000342
# [230]	eval-error:0.054638	train-error:0.000256
# [240]	eval-error:0.054838	train-error:0.000256
# Stopping. Best iteration:
# [233]	eval-error:0.054479	train-error:0.000222
# 0.7252834692659638

# %%
XGB_BO = BayesianOptimization(xgbf, {
#                                      'max_depth': (2, 12),
#                                      'gamma': (0.001, 10.0),
#                                      'min_child_weight': (0, 20),
#                                      'max_delta_step': (0, 10),
#                                      'subsample': (0.4, 1.0),
#                                      'colsample_bytree': (0.4, 1.0),
                                     'n_components': (50, 2000),
                                     'lamb': (1.0, 1.7),
                                     'alpha': (0.0, 0.5)
                                    })

XGB_BO.explore({
#               'max_depth':            [3, 8, 3, 8, 8, 3, 8, 3],
#               'gamma':                [0.5, 8, 0.2, 9, 0.5, 8, 0.2, 9],
#               'min_child_weight':     [0.2, 0.2, 0.2, 0.2, 12, 12, 12, 12],
#               'max_delta_step':       [1, 2, 2, 1, 2, 1, 1, 2],
#               'subsample':            [0.6, 0.8, 0.6, 0.8, 0.6, 0.8, 0.6, 0.8],
#               'colsample_bytree':     [0.6, 0.8, 0.6, 0.8, 0.6, 0.8, 0.6, 0.8],
              'n_components':         [50, 200, 400, 200, 1200, 600, 800, 750],
              'lamb':                 [1.0, 1.0, 1.2, 1.2, 1.4, 1.5, 1.0, 1.3],
              'alpha':                [0.0, 0.0, 0.15, 0.15, 0.25, 0.3, 0.1, 0.15]
              })

XGB_BO.maximize(init_points=2, n_iter=15, acq='ei', xi=0.0001)
# Out:
# Initialization
# ----------------------------------------------------------------------
#  Step |   Time |      Value |     alpha |      lamb |   n_components |
# [0]	eval-error:0.058188	train-error:0.052184
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.050371	train-error:0.041365
# [20]	eval-error:0.050371	train-error:0.037382
# [30]	eval-error:0.049972	train-error:0.033998
# [40]	eval-error:0.050451	train-error:0.02822
# [50]	eval-error:0.05061	train-error:0.02446
# [60]	eval-error:0.051567	train-error:0.021127
# [70]	eval-error:0.052126	train-error:0.016905
# [80]	eval-error:0.052285	train-error:0.015349
# [90]	eval-error:0.052205	train-error:0.01217
# [100]	eval-error:0.052205	train-error:0.00964
# [110]	eval-error:0.052405	train-error:0.00817
# [120]	eval-error:0.052883	train-error:0.007094
# [130]	eval-error:0.053841	train-error:0.005675
# [140]	eval-error:0.053163	train-error:0.004735
# [150]	eval-error:0.052804	train-error:0.003265
# [160]	eval-error:0.053442	train-error:0.002684
# [170]	eval-error:0.052883	train-error:0.001931
# [180]	eval-error:0.053362	train-error:0.001573
# [190]	eval-error:0.053721	train-error:0.001162
# [200]	eval-error:0.053801	train-error:0.000872
# [210]	eval-error:0.053362	train-error:0.000667
# [220]	eval-error:0.053402	train-error:0.000615
# [230]	eval-error:0.053801	train-error:0.000581
# [240]	eval-error:0.053841	train-error:0.00041
# [250]	eval-error:0.053761	train-error:0.000342
# [260]	eval-error:0.053601	train-error:0.000308
# [270]	eval-error:0.053801	train-error:0.000256
# Stopping. Best iteration:
# [261]	eval-error:0.053561	train-error:0.000256
#
#     1 | 00m08s |    0.72064 |    0.0000 |    1.0000 |        50.0000 |
# [0]	eval-error:0.058347	train-error:0.051637
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051767	train-error:0.040903
# [20]	eval-error:0.051009	train-error:0.03598
# [30]	eval-error:0.050849	train-error:0.030682
# [40]	eval-error:0.051368	train-error:0.022443
# [50]	eval-error:0.052804	train-error:0.016973
# [60]	eval-error:0.053043	train-error:0.012956
# [70]	eval-error:0.052684	train-error:0.010068
# [80]	eval-error:0.053083	train-error:0.007811
# [90]	eval-error:0.053801	train-error:0.005624
# [100]	eval-error:0.053881	train-error:0.004239
# [110]	eval-error:0.05396	train-error:0.00282
# [120]	eval-error:0.054479	train-error:0.002068
# [130]	eval-error:0.05412	train-error:0.001316
# [140]	eval-error:0.054519	train-error:0.000855
# [150]	eval-error:0.054239	train-error:0.000752
# [160]	eval-error:0.053681	train-error:0.000462
# [170]	eval-error:0.054319	train-error:0.000325
# [180]	eval-error:0.054718	train-error:0.000239
# [190]	eval-error:0.054917	train-error:0.000222
# Stopping. Best iteration:
# [181]	eval-error:0.054638	train-error:0.000222
#
#     2 | 00m18s |    0.72176 |    0.0000 |    1.0000 |       200.0000 |
# [0]	eval-error:0.058188	train-error:0.051056
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.050371	train-error:0.038596
# [20]	eval-error:0.049892	train-error:0.034545
# [30]	eval-error:0.05053	train-error:0.02834
# [40]	eval-error:0.051368	train-error:0.019776
# [50]	eval-error:0.052046	train-error:0.014871
# [60]	eval-error:0.052325	train-error:0.010632
# [70]	eval-error:0.053203	train-error:0.007846
# [80]	eval-error:0.053083	train-error:0.005658
# [90]	eval-error:0.053282	train-error:0.004171
# [100]	eval-error:0.053601	train-error:0.002752
# [110]	eval-error:0.053801	train-error:0.001931
# [120]	eval-error:0.054279	train-error:0.001145
# [130]	eval-error:0.054239	train-error:0.000838
# [140]	eval-error:0.05412	train-error:0.00041
# [150]	eval-error:0.055276	train-error:0.000256
# [160]	eval-error:0.054798	train-error:0.000205
# [170]	eval-error:0.055396	train-error:0.000171
# Stopping. Best iteration:
# [167]	eval-error:0.055436	train-error:0.000171
#
#     3 | 00m25s |    0.71370 |    0.1500 |    1.2000 |       400.0000 |
# [0]	eval-error:0.058228	train-error:0.051484
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051527	train-error:0.041006
# [20]	eval-error:0.05073	train-error:0.035194
# [30]	eval-error:0.050132	train-error:0.03034
# [40]	eval-error:0.051049	train-error:0.024015
# [50]	eval-error:0.051129	train-error:0.018358
# [60]	eval-error:0.051926	train-error:0.014751
# [70]	eval-error:0.052604	train-error:0.011521
# [80]	eval-error:0.053163	train-error:0.009367
# [90]	eval-error:0.053163	train-error:0.007059
# [100]	eval-error:0.053083	train-error:0.005641
# [110]	eval-error:0.053761	train-error:0.004068
# [120]	eval-error:0.053601	train-error:0.00282
# [130]	eval-error:0.053881	train-error:0.002068
# [140]	eval-error:0.053801	train-error:0.001504
# [150]	eval-error:0.0542	train-error:0.001265
# [160]	eval-error:0.054319	train-error:0.000786
# [170]	eval-error:0.053801	train-error:0.000598
# [180]	eval-error:0.05412	train-error:0.000393
# [190]	eval-error:0.054279	train-error:0.000273
# [200]	eval-error:0.054559	train-error:0.000188
# Stopping. Best iteration:
# [198]	eval-error:0.054678	train-error:0.000188
#
#     4 | 00m19s |    0.72782 |    0.1500 |    1.2000 |       200.0000 |
# [0]	eval-error:0.058985	train-error:0.051159
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051567	train-error:0.038767
# [20]	eval-error:0.05069	train-error:0.03275
# [30]	eval-error:0.051248	train-error:0.025024
# [40]	eval-error:0.052485	train-error:0.017913
# [50]	eval-error:0.053322	train-error:0.012888
# [60]	eval-error:0.054319	train-error:0.008529
# [70]	eval-error:0.054638	train-error:0.005743
# [80]	eval-error:0.055356	train-error:0.003778
# [90]	eval-error:0.055077	train-error:0.002325
# [100]	eval-error:0.055396	train-error:0.00135
# [110]	eval-error:0.055356	train-error:0.000803
# [120]	eval-error:0.054279	train-error:0.000427
# [130]	eval-error:0.054838	train-error:0.000308
# [140]	eval-error:0.055316	train-error:0.000256
# [150]	eval-error:0.055077	train-error:0.000188
# [160]	eval-error:0.054997	train-error:0.000171
# Stopping. Best iteration:
# [153]	eval-error:0.055077	train-error:0.000171
#
#     5 | 01m54s |    0.71655 |    0.2500 |    1.4000 |      1200.0000 |
# [0]	eval-error:0.058786	train-error:0.051159
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051328	train-error:0.039758
# [20]	eval-error:0.051408	train-error:0.033827
# [30]	eval-error:0.052245	train-error:0.027143
# [40]	eval-error:0.051607	train-error:0.020118
# [50]	eval-error:0.053322	train-error:0.014768
# [60]	eval-error:0.053362	train-error:0.010563
# [70]	eval-error:0.053881	train-error:0.006957
# [80]	eval-error:0.055396	train-error:0.004923
# [90]	eval-error:0.054798	train-error:0.003589
# [100]	eval-error:0.055236	train-error:0.002444
# [110]	eval-error:0.056234	train-error:0.001641
# [120]	eval-error:0.055835	train-error:0.001196
# [130]	eval-error:0.055476	train-error:0.000769
# [140]	eval-error:0.055715	train-error:0.000615
# [150]	eval-error:0.055635	train-error:0.000393
# [160]	eval-error:0.055994	train-error:0.000239
# [170]	eval-error:0.055994	train-error:0.000188
# Stopping. Best iteration:
# [167]	eval-error:0.056154	train-error:0.000188
#
#     6 | 00m44s |    0.71728 |    0.3000 |    1.5000 |       600.0000 |
# [0]	eval-error:0.058786	train-error:0.050817
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051049	train-error:0.038869
# [20]	eval-error:0.051129	train-error:0.033194
# [30]	eval-error:0.051248	train-error:0.026408
# [40]	eval-error:0.052883	train-error:0.018734
# [50]	eval-error:0.05404	train-error:0.01405
# [60]	eval-error:0.054758	train-error:0.009794
# [70]	eval-error:0.05404	train-error:0.006957
# [80]	eval-error:0.054399	train-error:0.004478
# [90]	eval-error:0.055077	train-error:0.002752
# [100]	eval-error:0.054917	train-error:0.001607
# [110]	eval-error:0.054758	train-error:0.001077
# [120]	eval-error:0.054838	train-error:0.00065
# [130]	eval-error:0.055396	train-error:0.000427
# [140]	eval-error:0.055436	train-error:0.000291
# [150]	eval-error:0.056194	train-error:0.000239
# [160]	eval-error:0.056034	train-error:0.000222
# [170]	eval-error:0.056632	train-error:0.000205
# [180]	eval-error:0.057071	train-error:0.000171
# Stopping. Best iteration:
# [175]	eval-error:0.056951	train-error:0.000171
#
#     7 | 01m09s |    0.71457 |    0.1000 |    1.0000 |       800.0000 |
# [0]	eval-error:0.058786	train-error:0.051244
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.05061	train-error:0.038784
# [20]	eval-error:0.050889	train-error:0.033724
# [30]	eval-error:0.050969	train-error:0.026665
# [40]	eval-error:0.052445	train-error:0.019212
# [50]	eval-error:0.053203	train-error:0.013623
# [60]	eval-error:0.054439	train-error:0.009914
# [70]	eval-error:0.055276	train-error:0.006393
# [80]	eval-error:0.056313	train-error:0.004188
# [90]	eval-error:0.055595	train-error:0.002803
# [100]	eval-error:0.056393	train-error:0.001795
# [110]	eval-error:0.056951	train-error:0.001043
# [120]	eval-error:0.05727	train-error:0.000513
# [130]	eval-error:0.056672	train-error:0.000342
# [140]	eval-error:0.057629	train-error:0.000256
# [150]	eval-error:0.057909	train-error:0.000205
# [160]	eval-error:0.057151	train-error:0.000171
# Stopping. Best iteration:
# [153]	eval-error:0.05743	train-error:0.000171
#
#     8 | 01m01s |    0.71193 |    0.1500 |    1.3000 |       750.0000 |
# [0]	eval-error:0.058946	train-error:0.050287
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.054279	train-error:0.037826
# [20]	eval-error:0.052564	train-error:0.030767
# [30]	eval-error:0.052764	train-error:0.023879
# [40]	eval-error:0.052285	train-error:0.016905
# [50]	eval-error:0.053522	train-error:0.010512
# [60]	eval-error:0.05392	train-error:0.006512
# [70]	eval-error:0.054598	train-error:0.003948
# [80]	eval-error:0.054997	train-error:0.002684
# [90]	eval-error:0.055356	train-error:0.001795
# [100]	eval-error:0.056114	train-error:0.000735
# [110]	eval-error:0.055715	train-error:0.000427
# [120]	eval-error:0.055835	train-error:0.000239
# [130]	eval-error:0.055954	train-error:0.000188
# Stopping. Best iteration:
# [124]	eval-error:0.055875	train-error:0.000188
#
#     9 | 02m49s |    0.71711 |    0.2031 |    1.1251 |      1746.7676 |
# [0]	eval-error:0.059344	train-error:0.051142
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.050132	train-error:0.037519
# [20]	eval-error:0.050451	train-error:0.031929
# [30]	eval-error:0.051248	train-error:0.024973
# [40]	eval-error:0.051488	train-error:0.01752
# [50]	eval-error:0.053043	train-error:0.012085
# [60]	eval-error:0.053123	train-error:0.008427
# [70]	eval-error:0.053442	train-error:0.005333
# [80]	eval-error:0.05408	train-error:0.003401
# [90]	eval-error:0.053761	train-error:0.002171
# [100]	eval-error:0.054878	train-error:0.001026
# [110]	eval-error:0.054239	train-error:0.000752
# [120]	eval-error:0.054917	train-error:0.000462
# [130]	eval-error:0.054239	train-error:0.000273
# [140]	eval-error:0.054559	train-error:0.000205
# Stopping. Best iteration:
# [138]	eval-error:0.054439	train-error:0.000171
#
#    10 | 02m22s |    0.71634 |    0.3406 |    1.2915 |      1468.3175 |
# Bayesian Optimization
# ----------------------------------------------------------------------
#  Step |   Time |      Value |     alpha |      lamb |   n_components |
# [0]	eval-error:0.058268	train-error:0.052048
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.05061	train-error:0.041348
# [20]	eval-error:0.049493	train-error:0.03716
# [30]	eval-error:0.050291	train-error:0.031673
# [40]	eval-error:0.05077	train-error:0.026169
# [50]	eval-error:0.051727	train-error:0.021708
# [60]	eval-error:0.051607	train-error:0.018289
# [70]	eval-error:0.052166	train-error:0.014922
# [80]	eval-error:0.053003	train-error:0.01217
# [90]	eval-error:0.052724	train-error:0.009999
# [100]	eval-error:0.052564	train-error:0.007726
# [110]	eval-error:0.053482	train-error:0.006102
# [120]	eval-error:0.052564	train-error:0.00523
# [130]	eval-error:0.053482	train-error:0.004119
# [140]	eval-error:0.05416	train-error:0.003231
# [150]	eval-error:0.054359	train-error:0.002444
# [160]	eval-error:0.05408	train-error:0.001692
# [170]	eval-error:0.053801	train-error:0.001419
# [180]	eval-error:0.05404	train-error:0.001162
# [190]	eval-error:0.054239	train-error:0.000906
# [200]	eval-error:0.053841	train-error:0.00053
# [210]	eval-error:0.054279	train-error:0.000393
# [220]	eval-error:0.053881	train-error:0.000308
# [230]	eval-error:0.053561	train-error:0.000291
# [240]	eval-error:0.053561	train-error:0.000205
# [250]	eval-error:0.053721	train-error:0.000188
# [260]	eval-error:0.054	train-error:0.000171
# Stopping. Best iteration:
# [256]	eval-error:0.054279	train-error:0.000171
#
#    11 | 00m18s |    0.72218 |    0.5000 |    1.7000 |       124.6105 |
# [0]	eval-error:0.058587	train-error:0.051381
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051966	train-error:0.037963
# [20]	eval-error:0.051089	train-error:0.032459
# [30]	eval-error:0.052006	train-error:0.024323
# [40]	eval-error:0.052844	train-error:0.017383
# [50]	eval-error:0.053801	train-error:0.012273
# [60]	eval-error:0.054878	train-error:0.007863
# [70]	eval-error:0.055875	train-error:0.005606
# [80]	eval-error:0.055715	train-error:0.00347
# [90]	eval-error:0.055276	train-error:0.002085
# [100]	eval-error:0.055117	train-error:0.001265
# [110]	eval-error:0.055635	train-error:0.000701
# [120]	eval-error:0.055914	train-error:0.000427
# [130]	eval-error:0.055635	train-error:0.000325
# [140]	eval-error:0.055635	train-error:0.000188
# Stopping. Best iteration:
# [138]	eval-error:0.055954	train-error:0.000171
#
#    12 | 02m08s |    0.71670 |    0.2062 |    1.3783 |      1331.2413 |
# [0]	eval-error:0.059145	train-error:0.050475
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.052405	train-error:0.038442
# [20]	eval-error:0.051208	train-error:0.032237
# [30]	eval-error:0.051647	train-error:0.025879
# [40]	eval-error:0.052325	train-error:0.01793
# [50]	eval-error:0.053282	train-error:0.012546
# [60]	eval-error:0.053442	train-error:0.008512
# [70]	eval-error:0.053881	train-error:0.005589
# [80]	eval-error:0.055476	train-error:0.003299
# [90]	eval-error:0.054917	train-error:0.002376
# [100]	eval-error:0.055037	train-error:0.001316
# [110]	eval-error:0.054878	train-error:0.000838
# [120]	eval-error:0.054399	train-error:0.000444
# [130]	eval-error:0.054638	train-error:0.000291
# [140]	eval-error:0.054997	train-error:0.000188
# [150]	eval-error:0.054838	train-error:0.000171
# Stopping. Best iteration:
# [144]	eval-error:0.054559	train-error:0.000171
#
#    13 | 02m46s |    0.71608 |    0.0000 |    1.7000 |      1618.4809 |
# [0]	eval-error:0.058826	train-error:0.050851
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.05057	train-error:0.039006
# [20]	eval-error:0.050092	train-error:0.032955
# [30]	eval-error:0.05053	train-error:0.026015
# [40]	eval-error:0.052285	train-error:0.018648
# [50]	eval-error:0.053003	train-error:0.013076
# [60]	eval-error:0.052923	train-error:0.009367
# [70]	eval-error:0.05416	train-error:0.006735
# [80]	eval-error:0.053721	train-error:0.004581
# [90]	eval-error:0.053402	train-error:0.003555
# [100]	eval-error:0.054279	train-error:0.002427
# [110]	eval-error:0.053721	train-error:0.00147
# [120]	eval-error:0.053761	train-error:0.000906
# [130]	eval-error:0.054598	train-error:0.00053
# [140]	eval-error:0.054239	train-error:0.000325
# [150]	eval-error:0.054838	train-error:0.000239
# [160]	eval-error:0.055077	train-error:0.000188
# [170]	eval-error:0.054838	train-error:0.000171
# Stopping. Best iteration:
# [169]	eval-error:0.054718	train-error:0.000171
#
#    14 | 01m38s |    0.72052 |    0.5000 |    1.7000 |      1010.2135 |
# [0]	eval-error:0.0609	train-error:0.049723
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051647	train-error:0.037963
# [20]	eval-error:0.052445	train-error:0.032271
# [30]	eval-error:0.053801	train-error:0.022631
# [40]	eval-error:0.054279	train-error:0.012717
# [50]	eval-error:0.053442	train-error:0.006529
# [60]	eval-error:0.05396	train-error:0.002923
# [70]	eval-error:0.054838	train-error:0.001761
# [80]	eval-error:0.053801	train-error:0.000684
# [90]	eval-error:0.053801	train-error:0.000273
# [100]	eval-error:0.053841	train-error:0.000171
# [110]	eval-error:0.0542	train-error:0.000171
# Stopping. Best iteration:
# [100]	eval-error:0.053841	train-error:0.000171
#
#    15 | 03m05s |    0.72081 |    0.5000 |    1.7000 |      1946.6662 |
# [0]	eval-error:0.06082	train-error:0.050783
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051567	train-error:0.038083
# [20]	eval-error:0.051767	train-error:0.030887
# [30]	eval-error:0.052285	train-error:0.022016
# [40]	eval-error:0.051687	train-error:0.014307
# [50]	eval-error:0.052405	train-error:0.008051
# [60]	eval-error:0.051926	train-error:0.003966
# [70]	eval-error:0.052365	train-error:0.002051
# [80]	eval-error:0.052804	train-error:0.000803
# [90]	eval-error:0.053203	train-error:0.000342
# [100]	eval-error:0.052764	train-error:0.000205
# [110]	eval-error:0.052844	train-error:0.000188
# [120]	eval-error:0.052764	train-error:0.000171
# Stopping. Best iteration:
# [111]	eval-error:0.052684	train-error:0.000171
#
#    16 | 03m00s |    0.72833 |    0.0000 |    1.7000 |      1855.6342 |
# [0]	eval-error:0.058148	train-error:0.051586
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051727	train-error:0.040322
# [20]	eval-error:0.051169	train-error:0.035075
# [30]	eval-error:0.051089	train-error:0.029724
# [40]	eval-error:0.051767	train-error:0.02311
# [50]	eval-error:0.052365	train-error:0.01764
# [60]	eval-error:0.053442	train-error:0.013914
# [70]	eval-error:0.053362	train-error:0.010051
# [80]	eval-error:0.054359	train-error:0.007487
# [90]	eval-error:0.05396	train-error:0.005658
# [100]	eval-error:0.053721	train-error:0.004171
# [110]	eval-error:0.05392	train-error:0.003008
# [120]	eval-error:0.053721	train-error:0.002051
# [130]	eval-error:0.05404	train-error:0.000974
# [140]	eval-error:0.05408	train-error:0.000718
# [150]	eval-error:0.053721	train-error:0.00053
# [160]	eval-error:0.05416	train-error:0.000342
# [170]	eval-error:0.054598	train-error:0.000239
# [180]	eval-error:0.054279	train-error:0.000205
# [190]	eval-error:0.054399	train-error:0.000188
# Stopping. Best iteration:
# [189]	eval-error:0.0542	train-error:0.000171
#
#    17 | 00m23s |    0.72263 |    0.5000 |    1.7000 |       298.3314 |
# /home/zach/dl_env/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.79217812e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 49, 'nit': 5, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# [0]	eval-error:0.058347	train-error:0.051313
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.050411	train-error:0.039023
# [20]	eval-error:0.049773	train-error:0.033587
# [30]	eval-error:0.050251	train-error:0.026596
# [40]	eval-error:0.051847	train-error:0.018665
# [50]	eval-error:0.052245	train-error:0.013469
# [60]	eval-error:0.053322	train-error:0.009435
# [70]	eval-error:0.053203	train-error:0.006803
# [80]	eval-error:0.054319	train-error:0.004769
# [90]	eval-error:0.054399	train-error:0.002889
# [100]	eval-error:0.054559	train-error:0.002102
# [110]	eval-error:0.055037	train-error:0.001145
# [120]	eval-error:0.055875	train-error:0.000598
# [130]	eval-error:0.055236	train-error:0.000444
# [140]	eval-error:0.054798	train-error:0.000325
# [150]	eval-error:0.055396	train-error:0.000205
# [160]	eval-error:0.055476	train-error:0.000188
# Stopping. Best iteration:
# [157]	eval-error:0.055595	train-error:0.000171
#
#    18 | 01m25s |    0.72175 |    0.5000 |    1.7000 |       915.6862 |
# [0]	eval-error:0.058427	train-error:0.051535
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051886	train-error:0.040151
# [20]	eval-error:0.050451	train-error:0.03451
# [30]	eval-error:0.050371	train-error:0.029024
# [40]	eval-error:0.051408	train-error:0.022169
# [50]	eval-error:0.052365	train-error:0.016717
# [60]	eval-error:0.052086	train-error:0.012016
# [70]	eval-error:0.053801	train-error:0.008564
# [80]	eval-error:0.055396	train-error:0.006205
# [90]	eval-error:0.055516	train-error:0.004786
# [100]	eval-error:0.055037	train-error:0.003504
# [110]	eval-error:0.055396	train-error:0.002496
# [120]	eval-error:0.055954	train-error:0.001555
# [130]	eval-error:0.055795	train-error:0.00106
# [140]	eval-error:0.056632	train-error:0.000564
# [150]	eval-error:0.056592	train-error:0.000444
# [160]	eval-error:0.056114	train-error:0.000308
# [170]	eval-error:0.055316	train-error:0.000239
# [180]	eval-error:0.056313	train-error:0.000205
# [190]	eval-error:0.056313	train-error:0.000171
# Stopping. Best iteration:
# [184]	eval-error:0.056154	train-error:0.000171
#
#    19 | 00m41s |    0.71685 |    0.5000 |    1.7000 |       502.5066 |
# [0]	eval-error:0.058467	train-error:0.050646
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.051926	train-error:0.038459
# [20]	eval-error:0.050969	train-error:0.032938
# [30]	eval-error:0.051049	train-error:0.025879
# [40]	eval-error:0.052604	train-error:0.01899
# [50]	eval-error:0.052285	train-error:0.013777
# [60]	eval-error:0.052445	train-error:0.010307
# [70]	eval-error:0.053482	train-error:0.007299
# [80]	eval-error:0.053561	train-error:0.005299
# [90]	eval-error:0.05416	train-error:0.003367
# [100]	eval-error:0.054399	train-error:0.002154
# [110]	eval-error:0.055037	train-error:0.001111
# [120]	eval-error:0.055037	train-error:0.000701
# [130]	eval-error:0.054957	train-error:0.000462
# [140]	eval-error:0.054957	train-error:0.000273
# [150]	eval-error:0.054838	train-error:0.000222
# [160]	eval-error:0.054598	train-error:0.000188
# Stopping. Best iteration:
# [158]	eval-error:0.054598	train-error:0.000188
#
#    20 | 01m48s |    0.71938 |    0.5000 |    1.7000 |      1107.3589 |
# [0]	eval-error:0.06086	train-error:0.050099
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.053003	train-error:0.037074
# [20]	eval-error:0.052604	train-error:0.029451
# [30]	eval-error:0.053282	train-error:0.020358
# [40]	eval-error:0.053362	train-error:0.011469
# [50]	eval-error:0.054359	train-error:0.006495

# %%
def xgbf(n_components, lamb, alpha):
    pca = PCA(n_components=int(n_components))
    X_train1 = pca.fit_transform(X_train)
    X_cv1 = pca.transform(X_cv)
    xgtrain = xgb.DMatrix(X_train1, y_train)
    xgcv = xgb.DMatrix(X_cv1, y_cv)
    # Specify sufficient boosting iterations to reach a minimum
    num_round = 5000
    evallist = [(xgcv, 'eval'), (xgtrain, 'train')]
    # Leave most parameters as default
    param = {'objective': 'binary:logistic',
             'tree_method': 'gpu_hist', # Use GPU accelerated algorithm
             'lambda': lamb,
             'alpha': alpha,
             }
    bst = xgb.train(param, xgtrain, num_round, evallist, early_stopping_rounds=10, verbose_eval = 10)
    
    pred = bst.predict(xgcv)
    
    f1_list = []
    thresholds = np.linspace(0.15, .55, 100)
    for i in thresholds:
        bin_pred = Binarizer(threshold=i).transform(pred.reshape(-1,1))
        f1 = f1_score(y_cv, bin_pred)
        f1_list.append(f1)
#     fig, ax = plt.subplots(figsize=(20, 10))
#     plt.plot(f1_list)
    return bst, thresholds[np.argmax(f1_list)]

# %%
bst, thresh = xgbf(1600, 1.7, 0)
# Out:
# [0]	eval-error:0.058108	train-error:0.050646
# Multiple eval metrics have been passed: 'train-error' will be used for early stopping.
#
# Will train until train-error hasn't improved in 10 rounds.
# [10]	eval-error:0.052445	train-error:0.036818
# [20]	eval-error:0.051847	train-error:0.030494
# [30]	eval-error:0.052006	train-error:0.02487
# [40]	eval-error:0.053282	train-error:0.017401
# [50]	eval-error:0.054559	train-error:0.012341
# [60]	eval-error:0.054957	train-error:0.007931
# [70]	eval-error:0.056034	train-error:0.005504
# [80]	eval-error:0.056752	train-error:0.003094
# [90]	eval-error:0.057031	train-error:0.001863
# [100]	eval-error:0.05727	train-error:0.001145
# [110]	eval-error:0.057789	train-error:0.000718
# [120]	eval-error:0.057948	train-error:0.00041
# [130]	eval-error:0.057789	train-error:0.000325
# [140]	eval-error:0.05759	train-error:0.000256
# [150]	eval-error:0.057749	train-error:0.000222
# Stopping. Best iteration:
# [146]	eval-error:0.057629	train-error:0.000222

# %%
# encode string input values as integers
features = []
encode_cols = ["month", "channelGrouping", "browser", "operatingSystem", "deviceCategory", "continent", 
                "subContinent", "country", "region", "metro", "city", "topLevelDomain", "campaign", "source", 
                "medium", "keyword", "referralPath", "adContent", "adwordsClickInfo.page", "adwordsClickInfo.slot",
                "adwordsClickInfo.adNetworkType", "bounces", "newVisits"]

other_cols = ["visitNumber", "timeSinceLastVisit", "isMobile", "isTrueDirect", "hits", "pageviews"]

# encode string input values as integers
encoded_x = None
for i in encode_cols:
    col = test[i].apply(str)
    label_encoder = LabelEncoder()
    feature = label_encoder.fit_transform(col.fillna('0'))
    feature = feature.reshape(test.shape[0], 1)
    onehot_encoder = OneHotEncoder(sparse=False)
    feature = onehot_encoder.fit_transform(feature)
    if encoded_x is None:
        encoded_x = feature
    else:
        encoded_x = np.concatenate((encoded_x, feature), axis=1)
print("X shape: ", encoded_x.shape)

test = np.concatenate((test[other_cols].fillna(0), encoded_x), axis=1)
# Out:
# X shape:  (56208, 2118)

# %%
pca = PCA(n_components=1600)
test1 = pca.fit_transform(test)
xgtest = xgb.DMatrix(test1)
pred = bst.predict(xgtest)

# %%
bin_pred = Binarizer(threshold=thresh).transform(pred.reshape(-1,1))

# %%
test_raw = pd.read_csv("data/Test.csv", encoding="ISO-8859-1")

# %%
sub = test_raw['sessionId']

# %%
sub = pd.DataFrame(sub)

# %%
sub['predictedClass'] = bin_pred

# %%
sub.astype(int)
# Out:
#            sessionId  predictedClass
# 0          100000110               0
# 1          200000120               0
# 2          500000150               0
# 3          500000250               0
# 4          700000170               0
# 5          800000180               0
# 6         1000000110               0
# 7         1200000112               0
# 8         1800000118               0
# 9         1800000218               0
# 10        1900000119               0
# 11        2200000122               0
# 12        2500000125               1
# 13        2600000126               0
# 14        2900000129               0
# 15        3500000135               0
# 16        3600000136               0
# 17        3700000137               0
# 18        3700000237               0
# 19        3700000337               0
# 20        4100000141               0
# 21        4200000142               0
# 22        4300000143               0
# 23        4700000147               0
# 24        4900000149               0
# 25        5200000152               0
# 26        5400000154               0
# 27        5500000155               0
# 28        5800000158               0
# 29        6200000162               1
# ...              ...             ...
# 56178  9447200000294               1
# 56179  9447200000394               0
# 56180  9447200000494               0
# 56181  9447200000594               0
# 56182  9447200000694               0
# 56183  9447200000794               1
# 56184  9447200000894               0
# 56185  9447200000994               1
# 56186  9447200001094               0
# 56187  9447200001194               0
# 56188  9447200001294               0
# 56189  9447200001394               0
# 56190  9447200001494               0
# 56191  9447200001594               0
# 56192  9447200001694               0
# 56193  9447200001794               0
# 56194  9447200001894               0
# 56195  9447300000194               0
# 56196  9447800000194               0
# 56197  9447900000194               0
# 56198  9448000000194               0
# 56199  9448200000194               1
# 56200  9448400000194               0
# 56201  9448600000194               0
# 56202  9448900000194               0
# 56203  9449100000194               0
# 56204  9449200000194               0
# 56205  9449300000194               0
# 56206  9449500000194               0
# 56207  9449700000194               0
#
# [56208 rows x 2 columns]
