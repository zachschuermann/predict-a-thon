# %%
# Load data into vectors
import pandas as pd

train = pd.read_csv('../binary_classification/data/Train.csv', encoding = "ISO-8859-1")
train.head()
# Out:
#    sessionId  custId        date  year  month channelGrouping  visitStartTime  \
# 0  100000110       1  2016-10-29  2016     10          Social      1477775021
# 1  400000140       4  2016-09-04  2016      9          Social      1473037945
# 2  500000150       5  2017-07-17  2017      7  Organic Search      1500305542
# 3  500000250       5  2017-07-17  2017      7  Organic Search      1500322111
# 4  700000170       7  2016-08-22  2016      8          Social      1471890172
#
#    visitNumber  timeSinceLastVisit browser   ...   adwordsClickInfo.page  \
# 0            1                   0  Chrome   ...                     NaN
# 1            1                   0  Safari   ...                     NaN
# 2            1                   0  Chrome   ...                     NaN
# 3            2               16569  Chrome   ...                     NaN
# 4            1                   0  Safari   ...                     NaN
#
#    adwordsClickInfo.slot adwordsClickInfo.gclId  \
# ...

# %%
import os
os.chdir('../data')
os.listdir()
# Out:
# ['Train.csv',
#  'Test.csv',
#  'SampleSubmission_revenue.csv',
#  'SampleSubmission_class.csv']

# %%
import data_loader as dl
a = dl.main()
a[0]
# Out:
#            sessionId  custId        date  year  month channelGrouping  \
# 0          100000110       1  2016-10-29  2016     10          Social
# 1          400000140       4  2016-09-04  2016      9          Social
# 2          500000150       5  2017-07-17  2017      7  Organic Search
# 3          500000250       5  2017-07-17  2017      7  Organic Search
# 4          700000170       7  2016-08-22  2016      8          Social
# 5          800000180       8  2017-05-18  2017      5          Direct
# 6          900000190       9  2016-10-09  2016     10          Social
# 7         1100000111      11  2017-03-03  2017      3  Organic Search
# 8         1200000112      12  2017-03-23  2017      3          Social
# 9         2000000120      20  2016-12-02  2016     12          Social
# 10        2200000122      22  2017-01-06  2017      1          Direct
# 11        2300000223      23  2017-03-04  2017      3          Direct
# ...
